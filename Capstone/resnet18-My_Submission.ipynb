# %% [markdown]
# <a href="http://cocl.us/pytorch_link_top">
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/Pytochtop.png" width="750" alt="IBM Product " />
# </a>

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0110EN/notebook_images%20/cc-logo-square.png" width="200" alt="cognitiveclass.ai logo" />

# %% [markdown]
# <h1><h1>Pre-trained-Models with PyTorch </h1>

# %% [markdown]
# In this lab, you will use pre-trained models to classify between the negative and positive samples; you will be provided with the dataset object. The particular pre-trained model will be resnet18; you will have three questions:
#
# <ul>
# <li>change the output layer</li>
# <li> train the model</li>
# <li>  identify  several  misclassified samples</li>
#  </ul>
# You will take several screenshots of your work and share your notebook.

# %% [markdown]
# <h2>Table of Contents</h2>

# %% [markdown]
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <ul>
#     <li><a href="#download_data"> Download Data</a></li>
#     <li><a href="#auxiliary"> Imports and Auxiliary Functions </a></li>
#     <li><a href="#data_class"> Dataset Class</a></li>
#     <li><a href="#Question_1">Question 1</a></li>
#     <li><a href="#Question_2">Question 2</a></li>
#     <li><a href="#Question_3">Question 3</a></li>
# </ul>
# <p>Estimated Time Needed: <strong>120 min</strong></p>
#  </div>
# <hr>

# %% [markdown]
# <h2 id="download_data">Download Data</h2>

# %% [markdown]
# Download the dataset and unzip the files in your data directory, unlike the other labs, all the data will be deleted after you close  the lab, this may take some time:

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Out:
# --2021-10-07 15:37:27--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Positive_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2598656062 (2.4G) [application/zip]
# Saving to: ‘Positive_tensors.zip.1’
#
# Positive_tensors.zi 100%[===================>]   2.42G  34.7MB/s    in 68s
#
# 2021-10-07 15:38:35 (36.3 MB/s) - ‘Positive_tensors.zip.1’ saved [2598656062/2598656062]

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
# !unzip -q Positive_tensors.zip
# Out:
# replace Positive_tensors/5114.pt? [y]es, [n]o, [A]ll, [N]one, [r]ename: ^C

# %%
y

# %%
! wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip 
# !unzip -q Negative_tensors.zip
# Out:
# --2021-10-07 15:43:37--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/Negative_tensors.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2111408108 (2.0G) [application/zip]
# Saving to: ‘Negative_tensors.zip.1’
#
# Negative_tensors.zi 100%[===================>]   1.97G  37.6MB/s    in 54s
#
# 2021-10-07 15:44:31 (37.4 MB/s) - ‘Negative_tensors.zip.1’ saved [2111408108/2111408108]

# %% [markdown]
# We will install torchvision:

# %%
# !pip install torchvision
# Out:
# Requirement already satisfied: torchvision in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (0.8.2)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from torchvision) (1.19.2)
# Requirement already satisfied: torch in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from torchvision) (1.7.1)
# Requirement already satisfied: pillow>=4.1.1 in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from torchvision) (8.3.1)
# Requirement already satisfied: typing_extensions in /opt/conda/envs/Python-3.8-main/lib/python3.8/site-packages (from torch->torchvision) (3.7.4.3)

# %% [markdown]
# <h2 id="auxiliary">Imports and Auxiliary Functions</h2>

# %% [markdown]
# The following are the libraries we are going to use for this lab. The <code>torch.manual_seed()</code> is for forcing the random function to give the same number every time we try to recompile it.

# %%
# These are the libraries will be used for this lab.
import torchvision.models as models
from PIL import Image
import pandas
from torchvision import transforms
import torch.nn as nn
import time
import torch 
import matplotlib.pylab as plt
import numpy as np
from torch.utils.data import Dataset, DataLoader
import h5py
import os
import glob
torch.manual_seed(0)

# %%
from matplotlib.pyplot import imshow
import matplotlib.pylab as plt
from PIL import Image
import pandas as pd
import os

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# <h2 id="data_class">Dataset Class</h2>

# %% [markdown]
#  This dataset class is essentially the same dataset you build in the previous section, but to speed things up, we are going to use tensors instead of jpeg images. Therefor for each iteration, you will skip the reshape step, conversion step to tensors and normalization step.

# %%
pwd
# Out:
# '/home/wsuser/work'

# %%
# Create your own dataset object

class Dataset(Dataset):

    # Constructor
    def __init__(self,transform=None,train=True):
        directory="/home/wsuser/work"
        positive="Positive_tensors"
        negative='Negative_tensors'

        positive_file_path=os.path.join(directory,positive)
        negative_file_path=os.path.join(directory,negative)
        positive_files=[os.path.join(positive_file_path,file) for file in os.listdir(positive_file_path) if file.endswith(".pt")]
        negative_files=[os.path.join(negative_file_path,file) for file in os.listdir(negative_file_path) if file.endswith(".pt")]
        number_of_samples=len(positive_files)+len(negative_files)
        self.all_files=[None]*number_of_samples
        self.all_files[::2]=positive_files
        self.all_files[1::2]=negative_files 
        # The transform is goint to be used on image
        self.transform = transform
        #torch.LongTensor
        self.Y=torch.zeros([number_of_samples]).type(torch.LongTensor)
        self.Y[::2]=1
        self.Y[1::2]=0
        
        if train:
            self.all_files=self.all_files[0:30000]
            self.Y=self.Y[0:30000]
            self.len=len(self.all_files)
        else:
            self.all_files=self.all_files[30000:]
            self.Y=self.Y[30000:]
            self.len=len(self.all_files)     
       
    # Get the length
    def __len__(self):
        return self.len
    
    # Getter
    def __getitem__(self, idx):
               
        image=torch.load(self.all_files[idx])
        y=self.Y[idx]
                  
        # If there is any transform method, apply it onto the image
        if self.transform:
            image = self.transform(image)

        return image, y
    
print("done")
# Out:
# done

# %% [markdown]
# We create two dataset objects, one for the training data and one for the validation data.

# %%
train_dataset = Dataset(train=True)
validation_dataset = Dataset(train=False)
print("done")
# Out:
# done

# %% [markdown]
# <h2 id="Question_1">Question 1</h2>

# %% [markdown]
# <b>Prepare a pre-trained resnet18 model :</b>

# %% [markdown]
# <b>Step 1</b>: Load the pre-trained model <code>resnet18</code> Set the parameter <code>pretrained</code> to true:

# %%
# Step 1: Load the pre-trained model resnet18

import torchvision.models as models

model = models.resnet18(pretrained=True)



model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %% [markdown]
# <b>Step 2</b>: Set the attribute <code>requires_grad</code> to <code>False</code>. As a result, the parameters will not be affected by training.

# %%
# Step 2: Set the parameter cannot be trained for the pre-trained model


for param in model.parameters():
    param.requires_grad = False

# %% [markdown]
# <code>resnet18</code> is used to classify 1000 different objects; as a result, the last layer has 1000 outputs.  The 512 inputs come from the fact that the previously hidden layer has 512 outputs.

# %% [markdown]
# <b>Step 3</b>: Replace the output layer <code>model.fc</code> of the neural network with a <code>nn.Linear</code> object, to classify 2 different classes. For the parameters <code>in_features </code> remember the last hidden layer has 512 neurons.

# %%
d_hidden = 512
d_out = 2

model.fc = nn.Linear(d_hidden, d_out)  # replace the output layer

# %% [markdown]
# Print out the model in order to show whether you get the correct answer.<br> <b>(Your peer reviewer is going to mark based on what you print here.)</b>

# %%
print(model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=2, bias=True)
# )

# %% [markdown]
# <h2 id="Question_2">Question 2: Train the Model</h2>

# %% [markdown]
# In this question you will train your, model:

# %% [markdown]
# <b>Step 1</b>: Create a cross entropy criterion function

# %%
# Step 1: Create the loss function

criterion = nn.CrossEntropyLoss()

# %% [markdown]
# <b>Step 2</b>: Create a training loader and validation loader object, the batch size should have 100 samples each.

# %%
batch_size = 100

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size)
validation_loader = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=batch_size)

# %%
# Verify the parameters whose requires_grad are True
for param in model.parameters():
  if param.requires_grad:
    print(param)
# Out:
# Parameter containing:
# tensor([[ 0.0295,  0.0391,  0.0264,  ..., -0.0092,  0.0206, -0.0118],
#         [-0.0395,  0.0435,  0.0007,  ...,  0.0081,  0.0211,  0.0269]],
#        requires_grad=True)
# Parameter containing:
# tensor([-0.0158, -0.0309], requires_grad=True)

# %% [markdown]
# <b>Step 3</b>: Use the following optimizer to minimize the loss

# %%
optimizer = torch.optim.Adam([parameters  for parameters in model.parameters() if parameters.requires_grad],lr=0.001)

# %% [markdown]
# <!--Empty Space for separating topics-->

# %% [markdown]
# **Complete the following code to calculate  the accuracy on the validation data for one epoch; this should take about 45 minutes. Make sure you calculate the accuracy on the validation data.**

# %%
n_epochs = 1
loss_list = []
accuracy_list = []
accuracy = 0
correct = 0
N_test = len(validation_dataset)
N_train = len(train_dataset)
start_time = time.time()
#n_epochs

print("Number of items in training set : ", N_train)
print("Number of items in testing set : ", N_test)

running_loss = 0
start_time = time.time()
for epoch in range(n_epochs):
    for i, (x, y) in enumerate(train_loader):        
        print('-' * 30)
        print('Iteration (train phase) {}/{}'.format(i+1, int(N_train/batch_size)))
        i_start_time = time.time()
        

            
        # set model to train 
        model.train() 
        
        # clear gradient 
        optimizer.zero_grad()
     
        # make a prediction 
        z = model(x)
   
        # calculate loss 
        loss = criterion(z, y) 
        # loss.requires_grad = True
    
        # calculate gradients of parameters 
        loss.backward()
        
        # update parameters 
        optimizer.step()
        
        loss_list.append(loss.data)
        print("Finished in {} (s)".format(time.time()-i_start_time))
    # end for
        
    correct=0
    for i, (x_test, y_test) in enumerate(validation_loader):
        print('-' * 30)
        print('Iteration (validation phase) {}/{}'.format(i+1, int(N_test/batch_size)))
        i_start_time = time.time()
        
        
        # set model to eval 
        model.eval()
       
        # make a prediction 
        z = model(x_test)
        
        # find max 
        _, yhat = torch.max(z.data, 1)
       
       
        #Calculate misclassified  samples in mini-batch 
        #hint +=(yhat==y_test).sum().item()
        correct += (yhat==y_test).sum().item()  
        
        print("Finished in {} (s)".format(time.time()-i_start_time))
    # end for
    
    accuracy=correct/N_test
    print("Epoch %d - accuracy: %.3f" % (epoch+1, accuracy))
    
    accuracy_list.append(accuracy)
    print("-" * 72)
    
    # Save model
    model_file_path = model_path + "resnet18_trained_model_epoch_{}.pth".format(epoch+1)
    torch.save(model.state_dict(), model_file_path)
    
    # Duration for epoch
    print("Finished epoch {} in {} (s).".format(epoch+1, time.time()-start_time))
# end for
# Out:
# Number of items in training set :  30000
# Number of items in testing set :  10000
# ------------------------------
# Iteration (train phase) 1/300
# Finished in 12.657734632492065 (s)
# ------------------------------
# Iteration (train phase) 2/300
# Finished in 10.156949043273926 (s)
# ------------------------------
# Iteration (train phase) 3/300
# Finished in 9.963244199752808 (s)
# ------------------------------
# Iteration (train phase) 4/300
# Finished in 10.107003688812256 (s)
# ------------------------------
# Iteration (train phase) 5/300
# Finished in 10.009790658950806 (s)
# ------------------------------
# Iteration (train phase) 6/300
# Finished in 10.154966592788696 (s)
# ------------------------------
# Iteration (train phase) 7/300
# Finished in 9.698965311050415 (s)
# ------------------------------
# Iteration (train phase) 8/300
# Finished in 10.067376613616943 (s)
# ------------------------------
# Iteration (train phase) 9/300
# Finished in 10.04244065284729 (s)
# ------------------------------
# Iteration (train phase) 10/300
# Finished in 10.101317405700684 (s)
# ------------------------------
# Iteration (train phase) 11/300
# Finished in 10.178266286849976 (s)
# ------------------------------
# Iteration (train phase) 12/300
# Finished in 10.025122165679932 (s)
# ------------------------------
# Iteration (train phase) 13/300
# Finished in 10.224979400634766 (s)
# ------------------------------
# Iteration (train phase) 14/300
# Finished in 9.986826419830322 (s)
# ------------------------------
# Iteration (train phase) 15/300
# Finished in 10.105897903442383 (s)
# ------------------------------
# Iteration (train phase) 16/300
# Finished in 10.060226678848267 (s)
# ------------------------------
# Iteration (train phase) 17/300
# Finished in 10.159074544906616 (s)
# ------------------------------
# Iteration (train phase) 18/300
# Finished in 9.906931638717651 (s)
# ------------------------------
# Iteration (train phase) 19/300
# Finished in 10.043611764907837 (s)
# ------------------------------
# Iteration (train phase) 20/300
# Finished in 9.904334783554077 (s)
# ------------------------------
# Iteration (train phase) 21/300
# Finished in 10.170309782028198 (s)
# ------------------------------
# Iteration (train phase) 22/300
# Finished in 10.349853515625 (s)
# ------------------------------
# Iteration (train phase) 23/300
# Finished in 10.26331114768982 (s)
# ------------------------------
# Iteration (train phase) 24/300
# Finished in 10.143329381942749 (s)
# ------------------------------
# Iteration (train phase) 25/300
# Finished in 10.374226570129395 (s)
# ------------------------------
# Iteration (train phase) 26/300
# Finished in 10.374391555786133 (s)
# ------------------------------
# Iteration (train phase) 27/300
# Finished in 10.442193269729614 (s)
# ------------------------------
# Iteration (train phase) 28/300
# Finished in 10.477891206741333 (s)
# ------------------------------
# Iteration (train phase) 29/300
# Finished in 10.341588497161865 (s)
# ------------------------------
# Iteration (train phase) 30/300
# Finished in 10.16533088684082 (s)
# ------------------------------
# Iteration (train phase) 31/300
# Finished in 10.209550142288208 (s)
# ------------------------------
# Iteration (train phase) 32/300
# Finished in 10.240200757980347 (s)
# ------------------------------
# Iteration (train phase) 33/300
# Finished in 10.37391471862793 (s)
# ------------------------------
# Iteration (train phase) 34/300
# Finished in 10.67333984375 (s)
# ------------------------------
# Iteration (train phase) 35/300
# Finished in 10.486236095428467 (s)
# ------------------------------
# Iteration (train phase) 36/300
# Finished in 10.51503300666809 (s)
# ------------------------------
# Iteration (train phase) 37/300
# Finished in 10.631534099578857 (s)
# ------------------------------
# Iteration (train phase) 38/300
# Finished in 10.658149719238281 (s)
# ------------------------------
# Iteration (train phase) 39/300
# Finished in 10.613054037094116 (s)
# ------------------------------
# Iteration (train phase) 40/300
# Finished in 10.516574382781982 (s)
# ------------------------------
# Iteration (train phase) 41/300
# Finished in 10.660617351531982 (s)
# ------------------------------
# Iteration (train phase) 42/300
# Finished in 10.402000188827515 (s)
# ------------------------------
# Iteration (train phase) 43/300
# Finished in 10.544235467910767 (s)
# ------------------------------
# Iteration (train phase) 44/300
# Finished in 10.419846534729004 (s)
# ------------------------------
# Iteration (train phase) 45/300
# Finished in 10.983362674713135 (s)
# ------------------------------
# Iteration (train phase) 46/300
# Finished in 10.413792371749878 (s)
# ------------------------------
# Iteration (train phase) 47/300
# Finished in 10.294636011123657 (s)
# ------------------------------
# Iteration (train phase) 48/300
# Finished in 9.989763736724854 (s)
# ------------------------------
# Iteration (train phase) 49/300
# Finished in 10.484578609466553 (s)
# ------------------------------
# Iteration (train phase) 50/300
# Finished in 10.382581233978271 (s)
# ------------------------------
# Iteration (train phase) 51/300
# Finished in 10.2055184841156 (s)
# ------------------------------
# Iteration (train phase) 52/300
# Finished in 10.129569053649902 (s)
# ------------------------------
# Iteration (train phase) 53/300
# Finished in 10.15738296508789 (s)
# ------------------------------
# Iteration (train phase) 54/300
# Finished in 10.293299913406372 (s)
# ------------------------------
# Iteration (train phase) 55/300
# Finished in 10.287030696868896 (s)
# ------------------------------
# Iteration (train phase) 56/300
# Finished in 10.345597982406616 (s)
# ------------------------------
# Iteration (train phase) 57/300
# Finished in 10.19813084602356 (s)
# ------------------------------
# Iteration (train phase) 58/300
# Finished in 10.655142068862915 (s)
# ------------------------------
# Iteration (train phase) 59/300
# Finished in 10.18256139755249 (s)
# ------------------------------
# Iteration (train phase) 60/300
# Finished in 10.4159677028656 (s)
# ------------------------------
# Iteration (train phase) 61/300
# Finished in 10.392659902572632 (s)
# ------------------------------
# Iteration (train phase) 62/300
# Finished in 10.418789863586426 (s)
# ------------------------------
# Iteration (train phase) 63/300
# Finished in 10.249081134796143 (s)
# ------------------------------
# Iteration (train phase) 64/300
# Finished in 10.056732416152954 (s)
# ------------------------------
# Iteration (train phase) 65/300
# Finished in 10.30115270614624 (s)
# ------------------------------
# Iteration (train phase) 66/300
# Finished in 10.315910816192627 (s)
# ------------------------------
# Iteration (train phase) 67/300
# Finished in 10.168553113937378 (s)
# ------------------------------
# Iteration (train phase) 68/300
# Finished in 10.398584842681885 (s)
# ------------------------------
# Iteration (train phase) 69/300
# Finished in 10.447855472564697 (s)
# ------------------------------
# Iteration (train phase) 70/300
# Finished in 10.41532015800476 (s)
# ------------------------------
# Iteration (train phase) 71/300
# Finished in 10.321917295455933 (s)
# ------------------------------
# Iteration (train phase) 72/300
# Finished in 10.385375261306763 (s)
# ------------------------------
# Iteration (train phase) 73/300
# Finished in 9.975861072540283 (s)
# ------------------------------
# Iteration (train phase) 74/300
# Finished in 10.299980640411377 (s)
# ------------------------------
# Iteration (train phase) 75/300
# Finished in 10.533635377883911 (s)
# ------------------------------
# Iteration (train phase) 76/300
# Finished in 10.49759030342102 (s)
# ------------------------------
# Iteration (train phase) 77/300
# Finished in 10.535369873046875 (s)
# ------------------------------
# Iteration (train phase) 78/300
# Finished in 10.446907997131348 (s)
# ------------------------------
# Iteration (train phase) 79/300
# Finished in 10.514240026473999 (s)
# ------------------------------
# Iteration (train phase) 80/300
# Finished in 10.644507646560669 (s)
# ------------------------------
# Iteration (train phase) 81/300
# Finished in 10.206056594848633 (s)
# ------------------------------
# Iteration (train phase) 82/300
# Finished in 10.265098333358765 (s)
# ------------------------------
# Iteration (train phase) 83/300
# Finished in 10.411816596984863 (s)
# ------------------------------
# Iteration (train phase) 84/300
# Finished in 10.663315057754517 (s)
# ------------------------------
# Iteration (train phase) 85/300
# Finished in 10.510430574417114 (s)
# ------------------------------
# Iteration (train phase) 86/300
# Finished in 10.510907649993896 (s)
# ------------------------------
# Iteration (train phase) 87/300
# Finished in 10.217162847518921 (s)
# ------------------------------
# Iteration (train phase) 88/300
# Finished in 10.919364213943481 (s)
# ------------------------------
# Iteration (train phase) 89/300
# Finished in 10.299277067184448 (s)
# ------------------------------
# Iteration (train phase) 90/300
# Finished in 10.495709419250488 (s)
# ------------------------------
# Iteration (train phase) 91/300
# Finished in 10.406233787536621 (s)
# ------------------------------
# Iteration (train phase) 92/300
# Finished in 10.49768877029419 (s)
# ------------------------------
# Iteration (train phase) 93/300
# Finished in 10.201293706893921 (s)
# ------------------------------
# Iteration (train phase) 94/300
# Finished in 10.44670581817627 (s)
# ------------------------------
# Iteration (train phase) 95/300
# Finished in 10.850403308868408 (s)
# ------------------------------
# Iteration (train phase) 96/300
# Finished in 10.411709785461426 (s)
# ------------------------------
# Iteration (train phase) 97/300
# Finished in 10.29267930984497 (s)
# ------------------------------
# Iteration (train phase) 98/300
# Finished in 10.654063701629639 (s)
# ------------------------------
# Iteration (train phase) 99/300
# Finished in 10.606902599334717 (s)
# ------------------------------
# Iteration (train phase) 100/300
# Finished in 10.542036771774292 (s)
# ------------------------------
# Iteration (train phase) 101/300
# Finished in 10.495059251785278 (s)
# ------------------------------
# Iteration (train phase) 102/300
# Finished in 10.608392238616943 (s)
# ------------------------------
# Iteration (train phase) 103/300
# Finished in 10.803057432174683 (s)
# ------------------------------
# Iteration (train phase) 104/300
# Finished in 10.438209056854248 (s)
# ------------------------------
# Iteration (train phase) 105/300
# Finished in 10.606393098831177 (s)
# ------------------------------
# Iteration (train phase) 106/300
# Finished in 10.326199531555176 (s)
# ------------------------------
# Iteration (train phase) 107/300
# Finished in 10.472963333129883 (s)
# ------------------------------
# Iteration (train phase) 108/300
# Finished in 10.716916799545288 (s)
# ------------------------------
# Iteration (train phase) 109/300
# Finished in 10.671958684921265 (s)
# ------------------------------
# Iteration (train phase) 110/300
# Finished in 10.19536542892456 (s)
# ------------------------------
# Iteration (train phase) 111/300
# Finished in 10.154757976531982 (s)
# ------------------------------
# Iteration (train phase) 112/300
# Finished in 10.599780559539795 (s)
# ------------------------------
# Iteration (train phase) 113/300
# Finished in 10.228508949279785 (s)
# ------------------------------
# Iteration (train phase) 114/300
# Finished in 10.537878274917603 (s)
# ------------------------------
# Iteration (train phase) 115/300
# Finished in 10.541798830032349 (s)
# ------------------------------
# Iteration (train phase) 116/300
# Finished in 10.38068151473999 (s)
# ------------------------------
# Iteration (train phase) 117/300
# Finished in 10.598788499832153 (s)
# ------------------------------
# Iteration (train phase) 118/300
# Finished in 10.453218221664429 (s)
# ------------------------------
# Iteration (train phase) 119/300
# Finished in 10.421284437179565 (s)
# ------------------------------
# Iteration (train phase) 120/300
# Finished in 10.415407180786133 (s)
# ------------------------------
# Iteration (train phase) 121/300
# Finished in 10.515711784362793 (s)
# ------------------------------
# Iteration (train phase) 122/300
# Finished in 10.623578310012817 (s)
# ------------------------------
# Iteration (train phase) 131/300
# Finished in 10.227123260498047 (s)
# ------------------------------
# Iteration (train phase) 132/300
# Finished in 10.570693731307983 (s)
# ------------------------------
# Iteration (train phase) 133/300
# Finished in 10.37573790550232 (s)
# ------------------------------
# Iteration (train phase) 134/300
# Finished in 10.323856353759766 (s)
# ------------------------------
# Iteration (train phase) 135/300
# Finished in 10.258676290512085 (s)
# ------------------------------
# Iteration (train phase) 136/300
# Finished in 9.886717796325684 (s)
# ------------------------------
# Iteration (train phase) 137/300
# Finished in 10.298927545547485 (s)
# ------------------------------
# Iteration (train phase) 138/300
# Finished in 10.511634111404419 (s)
# ------------------------------
# Iteration (train phase) 139/300
# Finished in 10.303252935409546 (s)
# ------------------------------
# Iteration (train phase) 140/300
# Finished in 10.407737970352173 (s)
# ------------------------------
# Iteration (train phase) 141/300
# Finished in 10.359119415283203 (s)
# ------------------------------
# Iteration (train phase) 142/300
# Finished in 10.349865913391113 (s)
# ------------------------------
# Iteration (train phase) 143/300
# Finished in 10.396527528762817 (s)
# ------------------------------
# Iteration (train phase) 144/300
# Finished in 10.457388877868652 (s)
# ------------------------------
# Iteration (train phase) 145/300
# Finished in 10.42349362373352 (s)
# ------------------------------
# Iteration (train phase) 146/300
# Finished in 10.613446712493896 (s)
# ------------------------------
# Iteration (train phase) 147/300
# Finished in 10.376287937164307 (s)
# ------------------------------
# Iteration (train phase) 148/300
# Finished in 10.305870771408081 (s)
# ------------------------------
# Iteration (train phase) 149/300
# Finished in 10.21050477027893 (s)
# ------------------------------
# Iteration (train phase) 150/300
# Finished in 10.610003471374512 (s)
# ------------------------------
# Iteration (train phase) 151/300
# Finished in 10.333073139190674 (s)
# ------------------------------
# Iteration (train phase) 152/300
# Finished in 10.167274713516235 (s)
# ------------------------------
# Iteration (train phase) 153/300
# Finished in 10.306178569793701 (s)
# ------------------------------
# Iteration (train phase) 154/300
# Finished in 10.3869788646698 (s)
# ------------------------------
# Iteration (train phase) 155/300
# Finished in 10.306243658065796 (s)
# ------------------------------
# Iteration (train phase) 156/300
# Finished in 10.256404161453247 (s)
# ------------------------------
# Iteration (train phase) 157/300
# Finished in 10.219613313674927 (s)
# ------------------------------
# Iteration (train phase) 158/300
# Finished in 10.098379373550415 (s)
# ------------------------------
# Iteration (train phase) 159/300
# Finished in 10.242201805114746 (s)
# ------------------------------
# Iteration (train phase) 160/300
# Finished in 10.078547239303589 (s)
# ------------------------------
# Iteration (train phase) 161/300
# Finished in 10.210418462753296 (s)
# ------------------------------
# Iteration (train phase) 162/300
# Finished in 10.047189950942993 (s)
# ------------------------------
# Iteration (train phase) 163/300
# Finished in 10.059777736663818 (s)
# ------------------------------
# Iteration (train phase) 164/300
# Finished in 10.075730323791504 (s)
# ------------------------------
# Iteration (train phase) 165/300
# Finished in 9.963529348373413 (s)
# ------------------------------
# Iteration (train phase) 166/300
# Finished in 10.294965505599976 (s)
# ------------------------------
# Iteration (train phase) 167/300
# Finished in 10.122791051864624 (s)
# ------------------------------
# Iteration (train phase) 168/300
# Finished in 10.303011417388916 (s)
# ------------------------------
# Iteration (train phase) 169/300
# Finished in 10.270854473114014 (s)
# ------------------------------
# Iteration (train phase) 170/300
# Finished in 10.360775232315063 (s)
# ------------------------------
# Iteration (train phase) 171/300
# Finished in 10.0282142162323 (s)
# ------------------------------
# Iteration (train phase) 172/300
# Finished in 10.329395294189453 (s)
# ------------------------------
# Iteration (train phase) 173/300
# Finished in 10.208980798721313 (s)
# ------------------------------
# Iteration (train phase) 174/300
# Finished in 10.187427043914795 (s)
# ------------------------------
# Iteration (train phase) 175/300
# Finished in 10.098006010055542 (s)
# ------------------------------
# Iteration (train phase) 176/300
# Finished in 10.170348882675171 (s)
# ------------------------------
# Iteration (train phase) 177/300
# Finished in 10.223294019699097 (s)
# ------------------------------
# Iteration (train phase) 178/300
# Finished in 10.268563270568848 (s)
# ------------------------------
# Iteration (train phase) 179/300
# Finished in 10.259405136108398 (s)
# ------------------------------
# Iteration (train phase) 180/300
# Finished in 9.9785737991333 (s)
# ------------------------------
# Iteration (train phase) 181/300
# Finished in 10.24756932258606 (s)
# ------------------------------
# Iteration (train phase) 182/300
# Finished in 10.204086303710938 (s)
# ------------------------------
# Iteration (train phase) 183/300
# Finished in 10.27203893661499 (s)
# ------------------------------
# Iteration (train phase) 184/300
# Finished in 10.06696367263794 (s)
# ------------------------------
# Iteration (train phase) 185/300
# Finished in 10.493295907974243 (s)
# ------------------------------
# Iteration (train phase) 186/300
# Finished in 10.068596839904785 (s)
# ------------------------------
# Iteration (train phase) 187/300
# Finished in 10.150939464569092 (s)
# ------------------------------
# Iteration (train phase) 188/300
# Finished in 10.148181438446045 (s)
# ------------------------------
# Iteration (train phase) 189/300
# Finished in 10.32976484298706 (s)
# ------------------------------
# Iteration (train phase) 190/300
# Finished in 10.130336046218872 (s)
# ------------------------------
# Iteration (train phase) 191/300
# Finished in 10.062612056732178 (s)
# ------------------------------
# Iteration (train phase) 192/300
# Finished in 10.165356874465942 (s)
# ------------------------------
# Iteration (train phase) 193/300
# Finished in 10.14029312133789 (s)
# ------------------------------
# Iteration (train phase) 194/300
# Finished in 9.937780857086182 (s)
# ------------------------------
# Iteration (train phase) 195/300
# Finished in 10.115867137908936 (s)
# ------------------------------
# Iteration (train phase) 196/300
# Finished in 10.146353960037231 (s)
# ------------------------------
# Iteration (train phase) 197/300
# Finished in 9.981196403503418 (s)
# ------------------------------
# Iteration (train phase) 198/300
# Finished in 10.175963640213013 (s)
# ------------------------------
# Iteration (train phase) 199/300
# Finished in 10.226130723953247 (s)
# ------------------------------
# Iteration (train phase) 200/300
# Finished in 10.317607641220093 (s)
# ------------------------------
# Iteration (train phase) 201/300
# Finished in 10.422730445861816 (s)
# ------------------------------
# Iteration (train phase) 202/300
# Finished in 10.234743118286133 (s)
# ------------------------------
# Iteration (train phase) 203/300
# Finished in 10.216372966766357 (s)
# ------------------------------
# Iteration (train phase) 204/300
# Finished in 10.209056615829468 (s)
# ------------------------------
# Iteration (train phase) 205/300
# Finished in 10.263071537017822 (s)
# ------------------------------
# Iteration (train phase) 206/300
# Finished in 10.369901657104492 (s)
# ------------------------------
# Iteration (train phase) 207/300
# Finished in 10.176638841629028 (s)
# ------------------------------
# Iteration (train phase) 208/300
# Finished in 10.385498285293579 (s)
# ------------------------------
# Iteration (train phase) 209/300
# Finished in 10.36555528640747 (s)
# ------------------------------
# Iteration (train phase) 210/300
# Finished in 10.13234543800354 (s)
# ------------------------------
# Iteration (train phase) 211/300
# Finished in 10.3056800365448 (s)
# ------------------------------
# Iteration (train phase) 212/300
# Finished in 10.165090322494507 (s)
# ------------------------------
# Iteration (train phase) 213/300
# Finished in 10.387656211853027 (s)
# ------------------------------
# Iteration (train phase) 214/300
# Finished in 10.329145193099976 (s)
# ------------------------------
# Iteration (train phase) 215/300
# Finished in 10.375863313674927 (s)
# ------------------------------
# Iteration (train phase) 216/300
# Finished in 10.18101191520691 (s)
# ------------------------------
# Iteration (train phase) 217/300
# Finished in 10.415625810623169 (s)
# ------------------------------
# Iteration (train phase) 218/300
# Finished in 10.610549211502075 (s)
# ------------------------------
# Iteration (train phase) 219/300
# Finished in 10.489288568496704 (s)
# ------------------------------
# Iteration (train phase) 220/300
# Finished in 10.579807758331299 (s)
# ------------------------------
# Iteration (train phase) 221/300
# Finished in 10.569136381149292 (s)
# ------------------------------
# Iteration (train phase) 222/300
# Finished in 10.188850164413452 (s)
# ------------------------------
# Iteration (train phase) 223/300
# Finished in 10.186109781265259 (s)
# ------------------------------
# Iteration (train phase) 224/300
# Finished in 10.103548765182495 (s)
# ------------------------------
# Iteration (train phase) 225/300
# Finished in 10.218959331512451 (s)
# ------------------------------
# Iteration (train phase) 226/300
# Finished in 10.314203023910522 (s)
# ------------------------------
# Iteration (train phase) 227/300
# Finished in 10.365175008773804 (s)
# ------------------------------
# Iteration (train phase) 228/300
# Finished in 10.13424277305603 (s)
# ------------------------------
# Iteration (train phase) 229/300
# Finished in 10.24970006942749 (s)
# ------------------------------
# Iteration (train phase) 230/300
# Finished in 10.15020227432251 (s)
# ------------------------------
# Iteration (train phase) 231/300
# Finished in 9.994041919708252 (s)
# ------------------------------
# Iteration (train phase) 232/300
# Finished in 10.177555799484253 (s)
# ------------------------------
# Iteration (train phase) 233/300
# Finished in 10.327649354934692 (s)
# ------------------------------
# Iteration (train phase) 234/300
# Finished in 10.107722759246826 (s)
# ------------------------------
# Iteration (train phase) 235/300
# Finished in 10.222413301467896 (s)
# ------------------------------
# Iteration (train phase) 236/300
# Finished in 10.269995927810669 (s)
# ------------------------------
# Iteration (train phase) 237/300
# Finished in 10.203019618988037 (s)
# ------------------------------
# Iteration (train phase) 238/300
# Finished in 10.264354467391968 (s)
# ------------------------------
# Iteration (train phase) 239/300
# Finished in 10.507610082626343 (s)
# ------------------------------
# Iteration (train phase) 240/300
# Finished in 10.366077899932861 (s)
# ------------------------------
# Iteration (train phase) 241/300
# Finished in 10.138231754302979 (s)
# ------------------------------
# Iteration (train phase) 242/300
# Finished in 10.242340564727783 (s)
# ------------------------------
# Iteration (train phase) 243/300
# Finished in 10.333128929138184 (s)
# ------------------------------
# Iteration (train phase) 244/300
# Finished in 10.155415058135986 (s)
# ------------------------------
# Iteration (train phase) 245/300
# Finished in 10.181018114089966 (s)
# ------------------------------
# Iteration (train phase) 246/300
# Finished in 10.239153861999512 (s)
# ------------------------------
# Iteration (train phase) 247/300
# Finished in 10.04542326927185 (s)
# ------------------------------
# Iteration (train phase) 248/300
# Finished in 10.07314419746399 (s)
# ------------------------------
# Iteration (train phase) 249/300
# Finished in 10.085720777511597 (s)
# ------------------------------
# Iteration (train phase) 250/300
# Finished in 10.248701810836792 (s)
# ------------------------------
# Iteration (train phase) 251/300
# Finished in 10.342268466949463 (s)
# ------------------------------
# Iteration (train phase) 252/300
# Finished in 10.397974491119385 (s)
# ------------------------------
# Iteration (train phase) 253/300
# Finished in 10.079090595245361 (s)
# ------------------------------
# Iteration (train phase) 254/300
# Finished in 10.285617351531982 (s)
# ------------------------------
# Iteration (train phase) 255/300
# Finished in 10.30073618888855 (s)
# ------------------------------
# Iteration (train phase) 256/300
# Finished in 10.292792320251465 (s)
# ------------------------------
# Iteration (train phase) 257/300
# Finished in 10.21390151977539 (s)
# ------------------------------
# Iteration (train phase) 258/300
# Finished in 10.241414070129395 (s)
# ------------------------------
# Iteration (train phase) 259/300
# Finished in 10.394864320755005 (s)
# ------------------------------
# Iteration (train phase) 260/300
# Finished in 10.224950551986694 (s)
# ------------------------------
# Iteration (train phase) 261/300
# Finished in 10.415151357650757 (s)
# ------------------------------
# Iteration (train phase) 262/300
# Finished in 10.143819093704224 (s)
# ------------------------------
# Iteration (train phase) 263/300
# Finished in 9.97695279121399 (s)
# ------------------------------
# Iteration (train phase) 264/300
# Finished in 10.29606032371521 (s)
# ------------------------------
# Iteration (train phase) 265/300
# Finished in 10.1576406955719 (s)
# ------------------------------
# Iteration (train phase) 266/300
# Finished in 10.272255659103394 (s)
# ------------------------------
# Iteration (train phase) 267/300
# Finished in 10.153138160705566 (s)
# ------------------------------
# Iteration (train phase) 268/300
# Finished in 10.244712591171265 (s)
# ------------------------------
# Iteration (train phase) 269/300
# Finished in 10.256524562835693 (s)
# ------------------------------
# Iteration (train phase) 270/300
# Finished in 10.21256685256958 (s)
# ------------------------------
# Iteration (train phase) 271/300
# Finished in 10.114989042282104 (s)
# ------------------------------
# Iteration (train phase) 272/300
# Finished in 10.290366172790527 (s)
# ------------------------------
# Iteration (train phase) 273/300
# Finished in 10.31803822517395 (s)
# ------------------------------
# Iteration (train phase) 274/300
# Finished in 10.305759191513062 (s)
# ------------------------------
# Iteration (train phase) 275/300
# Finished in 10.336992502212524 (s)
# ------------------------------
# Iteration (train phase) 276/300
# Finished in 10.26708436012268 (s)
# ------------------------------
# Iteration (train phase) 277/300
# Finished in 10.185021162033081 (s)
# ------------------------------
# Iteration (train phase) 278/300
# Finished in 10.198448657989502 (s)
# ------------------------------
# Iteration (train phase) 279/300
# Finished in 10.263766527175903 (s)
# ------------------------------
# Iteration (train phase) 280/300
# Finished in 10.157167911529541 (s)
# ------------------------------
# Iteration (train phase) 281/300
# Finished in 10.227202892303467 (s)
# ------------------------------
# Iteration (train phase) 282/300
# Finished in 10.108245372772217 (s)
# ------------------------------
# Iteration (train phase) 283/300
# Finished in 10.009392023086548 (s)
# ------------------------------
# Iteration (train phase) 284/300
# Finished in 10.188400030136108 (s)
# ------------------------------
# Iteration (train phase) 285/300
# Finished in 10.161662101745605 (s)
# ------------------------------
# Iteration (train phase) 286/300
# Finished in 10.22504186630249 (s)
# ------------------------------
# Iteration (train phase) 287/300
# Finished in 10.226217031478882 (s)
# ------------------------------
# Iteration (train phase) 288/300
# Finished in 10.307908773422241 (s)
# ------------------------------
# Iteration (train phase) 289/300
# Finished in 10.283015489578247 (s)
# ------------------------------
# Iteration (train phase) 290/300
# Finished in 10.42109751701355 (s)
# ------------------------------
# Iteration (train phase) 291/300
# Finished in 10.355765104293823 (s)
# ------------------------------
# Iteration (train phase) 292/300
# Finished in 10.234947443008423 (s)
# ------------------------------
# Iteration (train phase) 293/300
# Finished in 10.251930952072144 (s)
# ------------------------------
# Iteration (train phase) 294/300
# Finished in 10.351499557495117 (s)
# ------------------------------
# Iteration (train phase) 295/300
# Finished in 10.197145462036133 (s)
# ------------------------------
# Iteration (train phase) 296/300
# Finished in 10.21020770072937 (s)
# ------------------------------
# Iteration (train phase) 297/300
# Finished in 10.305182933807373 (s)
# ------------------------------
# Iteration (train phase) 298/300
# Finished in 10.168507814407349 (s)
# ------------------------------
# Iteration (train phase) 299/300
# Finished in 10.238082647323608 (s)
# ------------------------------
# Iteration (train phase) 300/300
# Finished in 10.061857223510742 (s)
# ------------------------------
# Iteration (validation phase) 1/100
# Finished in 10.042519330978394 (s)
# ------------------------------
# Iteration (validation phase) 2/100
# Finished in 10.03445053100586 (s)
# ------------------------------
# Iteration (validation phase) 3/100
# Finished in 9.992912292480469 (s)
# ------------------------------
# Iteration (validation phase) 4/100
# Finished in 9.631496906280518 (s)
# ------------------------------
# Iteration (validation phase) 5/100
# Finished in 9.670791149139404 (s)
# ------------------------------
# Iteration (validation phase) 6/100
# Finished in 9.816088914871216 (s)
# ------------------------------
# Iteration (validation phase) 7/100
# Finished in 9.790508508682251 (s)
# ------------------------------
# Iteration (validation phase) 8/100
# Finished in 10.01566219329834 (s)
# ------------------------------
# Iteration (validation phase) 9/100
# Finished in 9.735647439956665 (s)
# ------------------------------
# Iteration (validation phase) 10/100
# Finished in 9.759511709213257 (s)
# ------------------------------
# Iteration (validation phase) 11/100
# Finished in 9.873934507369995 (s)
# ------------------------------
# Iteration (validation phase) 12/100
# Finished in 9.824519872665405 (s)
# ------------------------------
# Iteration (validation phase) 13/100
# Finished in 9.658480882644653 (s)
# ------------------------------
# Iteration (validation phase) 14/100
# Finished in 9.868313789367676 (s)
# ------------------------------
# Iteration (validation phase) 15/100
# Finished in 9.808547258377075 (s)
# ------------------------------
# Iteration (validation phase) 16/100
# Finished in 9.761049032211304 (s)
# ------------------------------
# Iteration (validation phase) 17/100
# Finished in 10.002027750015259 (s)
# ------------------------------
# Iteration (validation phase) 18/100
# Finished in 9.846254110336304 (s)
# ------------------------------
# Iteration (validation phase) 19/100
# Finished in 9.862769603729248 (s)
# ------------------------------
# Iteration (validation phase) 20/100
# Finished in 10.138881921768188 (s)
# ------------------------------
# Iteration (validation phase) 21/100
# Finished in 9.742785215377808 (s)
# ------------------------------
# Iteration (validation phase) 22/100
# Finished in 9.693088293075562 (s)
# ------------------------------
# Iteration (validation phase) 23/100
# Finished in 9.721052408218384 (s)
# ------------------------------
# Iteration (validation phase) 24/100
# Finished in 9.48594856262207 (s)
# ------------------------------
# Iteration (validation phase) 25/100
# Finished in 9.757022619247437 (s)
# ------------------------------
# Iteration (validation phase) 26/100
# Finished in 9.834776639938354 (s)
# ------------------------------
# Iteration (validation phase) 27/100
# Finished in 9.48783564567566 (s)
# ------------------------------
# Iteration (validation phase) 28/100
# Finished in 9.941872119903564 (s)
# ------------------------------
# Iteration (validation phase) 29/100
# Finished in 9.857392311096191 (s)
# ------------------------------
# Iteration (validation phase) 30/100
# Finished in 9.803124189376831 (s)
# ------------------------------
# Iteration (validation phase) 31/100
# Finished in 9.785638093948364 (s)
# ------------------------------
# Iteration (validation phase) 32/100
# Finished in 9.927247285842896 (s)
# ------------------------------
# Iteration (validation phase) 33/100
# Finished in 9.720366477966309 (s)
# ------------------------------
# Iteration (validation phase) 34/100
# Finished in 9.91644811630249 (s)
# ------------------------------
# Iteration (validation phase) 35/100
# Finished in 9.884280681610107 (s)
# ------------------------------
# Iteration (validation phase) 36/100
# Finished in 10.121314525604248 (s)
# ------------------------------
# Iteration (validation phase) 37/100
# Finished in 9.721003770828247 (s)
# ------------------------------
# Iteration (validation phase) 38/100
# Finished in 9.862695932388306 (s)
# ------------------------------
# Iteration (validation phase) 39/100
# Finished in 9.985562086105347 (s)
# ------------------------------
# Iteration (validation phase) 40/100
# Finished in 9.958759546279907 (s)
# ------------------------------
# Iteration (validation phase) 41/100
# Finished in 9.935600996017456 (s)
# ------------------------------
# Iteration (validation phase) 42/100
# Finished in 9.761387586593628 (s)
# ------------------------------
# Iteration (validation phase) 43/100
# Finished in 9.603331327438354 (s)
# ------------------------------
# Iteration (validation phase) 44/100
# Finished in 9.98684048652649 (s)
# ------------------------------
# Iteration (validation phase) 45/100
# Finished in 9.774415969848633 (s)
# ------------------------------
# Iteration (validation phase) 46/100
# Finished in 9.856489658355713 (s)
# ------------------------------
# Iteration (validation phase) 47/100
# Finished in 9.798349857330322 (s)
# ------------------------------
# Iteration (validation phase) 48/100
# Finished in 9.691951990127563 (s)
# ------------------------------
# Iteration (validation phase) 49/100
# Finished in 9.887490510940552 (s)
# ------------------------------
# Iteration (validation phase) 50/100
# Finished in 9.65805959701538 (s)
# ------------------------------
# Iteration (validation phase) 51/100
# Finished in 9.905654191970825 (s)
# ------------------------------
# Iteration (validation phase) 52/100
# Finished in 9.80699110031128 (s)
# ------------------------------
# Iteration (validation phase) 53/100
# Finished in 9.69319748878479 (s)
# ------------------------------
# Iteration (validation phase) 54/100
# Finished in 10.006130933761597 (s)
# ------------------------------
# Iteration (validation phase) 55/100
# Finished in 9.844064474105835 (s)
# ------------------------------
# Iteration (validation phase) 56/100
# Finished in 9.9244225025177 (s)
# ------------------------------
# Iteration (validation phase) 57/100
# Finished in 9.797590970993042 (s)
# ------------------------------
# Iteration (validation phase) 58/100
# Finished in 9.85126280784607 (s)
# ------------------------------
# Iteration (validation phase) 59/100
# Finished in 9.778067827224731 (s)
# ------------------------------
# Iteration (validation phase) 60/100
# Finished in 10.125892400741577 (s)
# ------------------------------
# Iteration (validation phase) 61/100
# Finished in 9.922001600265503 (s)
# ------------------------------
# Iteration (validation phase) 62/100
# Finished in 9.916892528533936 (s)
# ------------------------------
# Iteration (validation phase) 63/100
# Finished in 10.031739950180054 (s)
# ------------------------------
# Iteration (validation phase) 64/100
# Finished in 9.819126844406128 (s)
# ------------------------------
# Iteration (validation phase) 65/100
# Finished in 9.935343742370605 (s)
# ------------------------------
# Iteration (validation phase) 66/100
# Finished in 9.59769058227539 (s)
# ------------------------------
# Iteration (validation phase) 67/100
# Finished in 9.903236150741577 (s)
# ------------------------------
# Iteration (validation phase) 68/100
# Finished in 9.719548225402832 (s)
# ------------------------------
# Iteration (validation phase) 69/100
# Finished in 9.817973136901855 (s)
# ------------------------------
# Iteration (validation phase) 70/100
# Finished in 9.794816732406616 (s)
# ------------------------------
# Iteration (validation phase) 71/100
# Finished in 10.114799737930298 (s)
# ------------------------------
# Iteration (validation phase) 72/100
# Finished in 10.015078783035278 (s)
# ------------------------------
# Iteration (validation phase) 73/100
# Finished in 9.69317102432251 (s)
# ------------------------------
# Iteration (validation phase) 74/100
# Finished in 9.843579292297363 (s)
# ------------------------------
# Iteration (validation phase) 75/100
# Finished in 9.876497030258179 (s)
# ------------------------------
# Iteration (validation phase) 76/100
# Finished in 9.851417541503906 (s)
# ------------------------------
# Iteration (validation phase) 77/100
# Finished in 9.771291494369507 (s)
# ------------------------------
# Iteration (validation phase) 78/100
# Finished in 10.151984453201294 (s)
# ------------------------------
# Iteration (validation phase) 79/100
# Finished in 9.708511352539062 (s)
# ------------------------------
# Iteration (validation phase) 80/100
# Finished in 9.672889232635498 (s)
# ------------------------------
# Iteration (validation phase) 81/100
# Finished in 9.857222557067871 (s)
# ------------------------------
# Iteration (validation phase) 82/100
# Finished in 9.736183166503906 (s)
# ------------------------------
# Iteration (validation phase) 83/100
# Finished in 9.837538480758667 (s)
# ------------------------------
# Iteration (validation phase) 84/100
# Finished in 9.94469404220581 (s)
# ------------------------------
# Iteration (validation phase) 85/100
# Finished in 10.165799140930176 (s)
# ------------------------------
# Iteration (validation phase) 86/100
# Finished in 9.654137372970581 (s)
# ------------------------------
# Iteration (validation phase) 87/100
# Finished in 10.000758647918701 (s)
# ------------------------------
# Iteration (validation phase) 88/100
# Finished in 9.932887554168701 (s)
# ------------------------------
# Iteration (validation phase) 89/100
# Finished in 10.00037693977356 (s)
# ------------------------------
# Iteration (validation phase) 90/100
# Finished in 9.869842767715454 (s)
# ------------------------------
# Iteration (validation phase) 91/100
# Finished in 9.661720037460327 (s)
# ------------------------------
# Iteration (validation phase) 92/100
# Finished in 9.83202052116394 (s)
# ------------------------------
# Iteration (validation phase) 93/100
# Finished in 9.715506315231323 (s)
# ------------------------------
# Iteration (validation phase) 94/100
# Finished in 9.68681001663208 (s)
# ------------------------------
# Iteration (validation phase) 95/100
# Finished in 9.662471055984497 (s)
# ------------------------------
# Iteration (validation phase) 96/100
# Finished in 10.076403141021729 (s)
# ------------------------------
# Iteration (validation phase) 97/100
# Finished in 9.88474416732788 (s)
# ------------------------------
# Iteration (validation phase) 98/100
# Finished in 9.735887289047241 (s)
# ------------------------------
# Iteration (validation phase) 99/100
# Finished in 9.841778993606567 (s)
# ------------------------------
# Iteration (validation phase) 100/100
# Finished in 9.734666585922241 (s)
# Epoch 1 - accuracy: 0.994
# ------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-a53bdfff0fd6> in <module>
#      76
#      77     # Save model
# ---> 78     model_file_path = model_path + "resnet18_trained_model_epoch_{}.pth".format(epoch+1)
#      79     torch.save(model.state_dict(), model_file_path)
#      80
#
# NameError: name 'model_path' is not defined

# %% [markdown]
# <b>Print out the Accuracy and plot the loss stored in the list <code>loss_list</code> for every iteration and take a screen shot.</b>

# %%
accuracy
# Out:
# 0.9939

# %%
plt.plot(loss_list)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.show()

# %% [markdown]
# <h2 id="Question_3">Question 3:Find the misclassified samples</h2>

# %% [markdown]
# <b>Identify the first four misclassified samples using the validation data:</b>

# %%
count = 0
max_num_of_items = 4  # first four mis-classified samples
validation_loader_batch_one = torch.utils.data.DataLoader(dataset=validation_dataset, batch_size=1)

for i, (x_test, y_test) in enumerate(validation_loader_batch_one):
    # set model to eval
    model.eval()
    
    # make a prediction
    z = model(x_test)
    
    # find max
    _, yhat = torch.max(z.data, 1)
    
    # print mis-classified samples
    if yhat != y_test:
        print("Sample : {}; Expected Label: {}; Obtained Label: {}".format(str(i), str(y_test), str(yhat)))
        count += 1
        if count >= max_num_of_items:
            break
    # end if
# end for
# Out:
# Sample : 117; Expected Label: tensor([0]); Obtained Label: tensor([1])
# Sample : 316; Expected Label: tensor([1]); Obtained Label: tensor([0])
# Sample : 361; Expected Label: tensor([0]); Obtained Label: tensor([1])
# Sample : 434; Expected Label: tensor([1]); Obtained Label: tensor([0])

# %% [markdown]
# <a href="https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/share-notebooks.html"> CLICK HERE </a> Click here to see how to share your notebook.

# %% [markdown]
# <h2>About the Authors:</h2>
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description                                          |
# | ----------------- | ------- | ---------- | ----------------------------------------------------------- |
# | 2020-09-21        | 2.0     | Shubham    | Migrated Lab to Markdown and added to course repo in GitLab |
#
# <hr>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>

# %% [markdown]
# Copyright © 2018 <a href="cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu">cognitiveclass.ai</a>. This notebook and its source code are released under the terms of the <a href="https://bigdatauniversity.com/mit-license/">MIT License</a>.
